# %%
from urllib import response

from langchain_core.messages import HumanMessage
from langchain_core.tools import tool
from dotenv import load_dotenv
from langchain.agents import create_agent
from langchain.chat_models import init_chat_model
from sympy import true
from rich import print as rprint

load_dotenv(override=True)

model = init_chat_model(
    model="deepseek:deepseek-v4-flash"
)

@tool(parse_docstring=true)
def get_weather(city: str) -> str:
    """
    get weather

    Args:
        city (str): city name

    Returns:
        str: weather
    """
    return f"{city} is sunny today"

agent = create_agent(
    model=model,
    tools=[get_weather],
    name="Agent-01"
)

response = agent.invoke({
    "messages": [
        HumanMessage("How is the weather in Beijing?")
    ]
})

rprint(response)
# Out:
# {
#     'messages': [
#         HumanMessage(
#             content='How is the weather in Beijing?',
#             additional_kwargs={},
#             response_metadata={},
#             id='80dccb30-2606-41cb-a446-3e2a08dad118'
#         ),
#         AIMessage(
#             content='',
#             additional_kwargs={
#                 'refusal': None,
#                 'reasoning_content': 'The user is asking about the weather in Beijing. Let me call the get_weather
# function with the city parameter.'
#             },
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 68,
#                     'prompt_tokens': 283,
#                     'total_tokens': 351,
#                     'completion_tokens_details': {
#                         'accepted_prediction_tokens': None,
#                         'audio_tokens': None,
#                         'reasoning_tokens': 23,
#                         'rejected_prediction_tokens': None
#                     },
#                     'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 256},
#                     'prompt_cache_hit_tokens': 256,
#                     'prompt_cache_miss_tokens': 27
#                 },
#                 'model_provider': 'deepseek',
#                 'model_name': 'deepseek-v4-flash',
#                 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402',
#                 'id': 'c9179caa-f86e-4699-9c72-fabc0427edec',
#                 'finish_reason': 'tool_calls',
#                 'logprobs': None
#             },
#             name='Agent-01',
#             id='lc_run--019f743f-e933-7503-9128-30d38bcb93d7-0',
#             tool_calls=[
#                 {
#                     'name': 'get_weather',
#                     'args': {'city': 'Beijing'},
#                     'id': 'call_00_XcIPA4z2DpocDRDGalLi5341',
#                     'type': 'tool_call'
#                 }
#             ],
#             invalid_tool_calls=[],
#             usage_metadata={
#                 'input_tokens': 283,
#                 'output_tokens': 68,
#                 'total_tokens': 351,
#                 'input_token_details': {'cache_read': 256},
#                 'output_token_details': {'reasoning': 23}
#             }
#         ),
#         ToolMessage(
#             content='Beijing is sunny today',
#             name='get_weather',
#             id='c488cc5f-c522-4cc2-90ce-a2abee02ddf9',
#             tool_call_id='call_00_XcIPA4z2DpocDRDGalLi5341'
#         ),
#         AIMessage(
#             content='The weather in Beijing is **sunny** today! 🌞',
#             additional_kwargs={'refusal': None, 'reasoning_content': 'The weather in Beijing is sunny today.'},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 22,
#                     'prompt_tokens': 367,
#                     'total_tokens': 389,
#                     'completion_tokens_details': {
#                         'accepted_prediction_tokens': None,
#                         'audio_tokens': None,
#                         'reasoning_tokens': 8,
#                         'rejected_prediction_tokens': None
#                     },
#                     'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 256},
#                     'prompt_cache_hit_tokens': 256,
#                     'prompt_cache_miss_tokens': 111
#                 },
#                 'model_provider': 'deepseek',
#                 'model_name': 'deepseek-v4-flash',
#                 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402',
#                 'id': 'f2c82168-1f0e-4928-9656-292e4a251f36',
#                 'finish_reason': 'stop',
#                 'logprobs': None
#             },
#             name='Agent-01',
#             id='lc_run--019f743f-eec1-74d3-afd7-60b343a503df-0',
#             tool_calls=[],
#             invalid_tool_calls=[],
#             usage_metadata={
#                 'input_tokens': 367,
#                 'output_tokens': 22,
#                 'total_tokens': 389,
#                 'input_token_details': {'cache_read': 256},
#                 'output_token_details': {'reasoning': 8}
#             }
#         )
#     ]
# }
