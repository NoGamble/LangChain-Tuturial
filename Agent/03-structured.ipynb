# %%
from langchain.agents import create_agent
from langchain.agents.structured_output import ToolStrategy, AutoStrategy
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
from langchain_core.messages import HumanMessage
from pydantic import BaseModel, Field
from rich import print as rprint

# Load up the config
load_dotenv(override=True)

model = init_chat_model(
    model="deepseek:deepseek-chat",
)

class ContractInfo(BaseModel):
    name: str = Field(description="name of the user")
    email: str = Field(description="email address of the user")
    phone: str = Field(description="phone number of the user")

agent = create_agent(
    model=model,
    name="Agent01",
    response_format=AutoStrategy(ContractInfo),
)


messages = [
    HumanMessage("从以下信息中提取用户信息，小明的邮箱是ming@gmail.com，电话是520-666")
]

response = agent.invoke({
    "messages": messages,
})

rprint(response)
# Out:
# {
#     'messages': [
#         HumanMessage(
#             content='从以下信息中提取用户信息，小明的邮箱是ming@gmail.com，电话是520-666',
#             additional_kwargs={},
#             response_metadata={},
#             id='12213562-c37b-46c2-bbfb-85b09bc47b59'
#         ),
#         AIMessage(
#             content='',
#             additional_kwargs={'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 72,
#                     'prompt_tokens': 346,
#                     'total_tokens': 418,
#                     'completion_tokens_details': None,
#                     'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 256},
#                     'prompt_cache_hit_tokens': 256,
#                     'prompt_cache_miss_tokens': 90
#                 },
#                 'model_provider': 'deepseek',
#                 'model_name': 'deepseek-v4-flash',
#                 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402',
#                 'id': '8429f9ea-b609-4c5c-ab15-172cc4d40135',
#                 'finish_reason': 'tool_calls',
#                 'logprobs': None
#             },
#             name='Agent01',
#             id='lc_run--019f7968-6005-7990-868e-fa34d675109b-0',
#             tool_calls=[
#                 {
#                     'name': 'ContractInfo',
#                     'args': {'name': '小明', 'email': 'ming@gmail.com', 'phone': '520-666'},
#                     'id': 'call_00_o2sSsiu9xMDQWbqN6tAf3613',
#                     'type': 'tool_call'
#                 }
#             ],
#             invalid_tool_calls=[],
#             usage_metadata={
#                 'input_tokens': 346,
#                 'output_tokens': 72,
#                 'total_tokens': 418,
#                 'input_token_details': {'cache_read': 256},
#                 'output_token_details': {}
#             }
#         ),
#         ToolMessage(
#             content="Returning structured response: name='小明' email='ming@gmail.com' phone='520-666'",
#             name='ContractInfo',
#             id='15aff41e-e355-4eb6-8978-581934f495d1',
#             tool_call_id='call_00_o2sSsiu9xMDQWbqN6tAf3613'
#         )
#     ],
#     'structured_response': ContractInfo(name='小明', email='ming@gmail.com', phone='520-666')
# }
