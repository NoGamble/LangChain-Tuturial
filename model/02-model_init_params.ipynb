# %% [markdown]
# # Params of init_chat_model
# ## Temperature
# - logits/temperature -> the large numbers become larger, small ones smaller
# - which leads to low temperature -> less creative, while high temp -> more creative and adventurous

# %%
import os

from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
from sympy.physics.units import temperature

load_dotenv(override=True)

DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

model = init_chat_model(
    model="deepseek:deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
    temperature=0.1
)
response = model.invoke("write a 4 lines poem of winter").content
print(response)
# Out:
# The frost has etched a lacework on the pane,
# The stubborn earth has hardened with the cold.
# A silence wraps the world in white and gray,
# A story that the northern winds have told.

# %%
import os

from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

load_dotenv(override=True)

DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

model = init_chat_model(
    model="deepseek:deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
    temperature=2
)
response = model.invoke("write a 4 lines poem of winter").content
print(response)
# Out:
# Snowflakes fall on silent ground,
# Bare trees shiver, no birds make sound.
# A breath of frost hangs in the air,
# Winter’s quiet, everywhere.

# %% [markdown]
# ## max_tokens

# %%
import os

from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

load_dotenv(override=True)

DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

model = init_chat_model(
    model="deepseek:deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
    max_tokens=10,
)
response = model.invoke("write a 4 lines poem of winter")
print(response)
# Out:
# content='' additional_kwargs={'refusal': None, 'reasoning_content': 'We need to write a 4-line poem about'} response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 12, 'total_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 10, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 12}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': '13bf3b1f-a9e4-423d-a483-a0604ad1309d', 'finish_reason': 'length', 'logprobs': None} id='lc_run--019f6a04-19ca-7bb1-b81e-9e9cb51c9db1-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 12, 'output_tokens': 10, 'total_tokens': 22, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 10}}
