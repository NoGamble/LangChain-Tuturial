# %% [markdown]
# # Profile

# %%
from babel.messages.setuptools_frontend import init_catalog
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
import os

load_dotenv(override=True)

DEEPSEEK_API_KEY=os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL=os.getenv("DEEPSEEK_BASE_URL")

model = init_chat_model(
    model="deepseek:deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
)

# %%
print(model.profile)
# Out:
# {}

# %%
from langchain_openrouter import ChatOpenRouter
import os
from rich import print as rprint

load_dotenv(override=True)
OPENROUTER_API_KEY=os.getenv("OPENROUTER_API_KEY")
OPENROUTER_API_BASE=os.getenv("OPENROUTER_API_BASE")

model = ChatOpenRouter(
    model="openai/gpt-4o-mini",
    api_key=OPENROUTER_API_KEY,
    base_url=OPENROUTER_API_BASE,
)
rprint(model.profile)
# Out:
# {
#     'max_input_tokens': 128000,
#     'max_output_tokens': 16384,
#     'text_inputs': True,
#     'image_inputs': True,
#     'audio_inputs': False,
#     'video_inputs': False,
#     'text_outputs': True,
#     'image_outputs': False,
#     'audio_outputs': False,
#     'video_outputs': False,
#     'reasoning_output': False,
#     'tool_calling': True,
#     'structured_output': True
# }

# %% [markdown]
# # Init Params

# %%
from langchain_deepseek import ChatDeepSeek
rprint(ChatDeepSeek.model_fields.keys())
# Out:
# dict_keys(['name', 'cache', 'verbose', 'callbacks', 'tags', 'metadata', 'custom_get_token_ids', 'rate_limiter',
# 'disable_streaming', 'output_version', 'profile', 'client', 'async_client', 'root_client', 'root_async_client',
# 'model_name', 'temperature', 'model_kwargs', 'openai_api_key', 'openai_api_base', 'openai_organization',
# 'openai_proxy', 'request_timeout', 'stream_usage', 'max_retries', 'presence_penalty', 'frequency_penalty', 'seed',
# 'logprobs', 'top_logprobs', 'logit_bias', 'streaming', 'n', 'top_p', 'max_tokens', 'reasoning_effort', 'reasoning',
# 'verbosity', 'tiktoken_model_name', 'default_headers', 'default_query', 'http_client', 'http_async_client', 'stop',
# 'extra_body', 'include_response_headers', 'disabled_params', 'context_management', 'include', 'service_tier',
# 'store', 'truncation', 'use_previous_response_id', 'use_responses_api', 'api_key', 'api_base'])

# %%
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
import os

load_dotenv(override=True)

DEEPSEEK_API_KEY=os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL=os.getenv("DEEPSEEK_BASE_URL")

model = init_chat_model(
    model="deepseek:deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
)
rprint(ChatDeepSeek.model_fields.keys())
# Out:
# dict_keys(['name', 'cache', 'verbose', 'callbacks', 'tags', 'metadata', 'custom_get_token_ids', 'rate_limiter',
# 'disable_streaming', 'output_version', 'profile', 'client', 'async_client', 'root_client', 'root_async_client',
# 'model_name', 'temperature', 'model_kwargs', 'openai_api_key', 'openai_api_base', 'openai_organization',
# 'openai_proxy', 'request_timeout', 'stream_usage', 'max_retries', 'presence_penalty', 'frequency_penalty', 'seed',
# 'logprobs', 'top_logprobs', 'logit_bias', 'streaming', 'n', 'top_p', 'max_tokens', 'reasoning_effort', 'reasoning',
# 'verbosity', 'tiktoken_model_name', 'default_headers', 'default_query', 'http_client', 'http_async_client', 'stop',
# 'extra_body', 'include_response_headers', 'disabled_params', 'context_management', 'include', 'service_tier',
# 'store', 'truncation', 'use_previous_response_id', 'use_responses_api', 'api_key', 'api_base'])

# %% [markdown]
# # model_kwargs
# langchain lacks the args, but the models have

# %%
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
import os

load_dotenv(override=True)

DEEPSEEK_API_KEY=os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL=os.getenv("DEEPSEEK_BASE_URL")

model = init_chat_model(
    model="deepseek:deepseek-v4-flash",
    model_kwargs={'tools': [
        {
            "type": "function",
            "function": {
                "name": "get_weather",
                "description": "Get a weather of a location, the user should supply a location first",
                "parameters": {
                    "type": "object",
                    "properties": {
                        "location": {
                            "type": "string",
                            "description": "The city and state, e. g. San Francisco, CA",
                        }
                    },
                    "required": ["location"]
                }
            }
        }
    ]},
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
)

# %%
response = model.invoke("how is the weather today at Beijing?")
rprint(response)
# Out:
# AIMessage(
#     content='',
#     additional_kwargs={
#         'refusal': None,
#         'reasoning_content': 'The user is asking about the weather in Beijing. Let me get the weather information
# for Beijing.'
#     },
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 66,
#             'prompt_tokens': 307,
#             'total_tokens': 373,
#             'completion_tokens_details': {
#                 'accepted_prediction_tokens': None,
#                 'audio_tokens': None,
#                 'reasoning_tokens': 19,
#                 'rejected_prediction_tokens': None
#             },
#             'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 256},
#             'prompt_cache_hit_tokens': 256,
#             'prompt_cache_miss_tokens': 51
#         },
#         'model_provider': 'deepseek',
#         'model_name': 'deepseek-v4-flash',
#         'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402',
# ...

# %%
response = model.invoke("1 + 1 = ?")
rprint(response)
# Out:
# AIMessage(
#     content='1 + 1 = **2**',
#     additional_kwargs={
#         'refusal': None,
#         'reasoning_content': 'The user is asking a simple math question: 1 + 1 = ?. I know the answer is 2. Let me
# provide the answer directly.'
#     },
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 41,
#             'prompt_tokens': 305,
#             'total_tokens': 346,
#             'completion_tokens_details': {
#                 'accepted_prediction_tokens': None,
#                 'audio_tokens': None,
#                 'reasoning_tokens': 32,
#                 'rejected_prediction_tokens': None
#             },
#             'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 256},
#             'prompt_cache_hit_tokens': 256,
#             'prompt_cache_miss_tokens': 49
#         },
#         'model_provider': 'deepseek',
#         'model_name': 'deepseek-v4-flash',
# ...

# %%
model = init_chat_model(
    model="deepseek:deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
    extra_body = {"thinking": {"type": "disabled"}}
)

rprint(model.invoke("1 + 1 = ?"))
# Out:
# AIMessage(
#     content='1 + 1 = 2.\n\nThis is a basic arithmetic operation where adding one unit to another unit results in a
# total of two units.',
#     additional_kwargs={'refusal': None},
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 29,
#             'prompt_tokens': 10,
#             'total_tokens': 39,
#             'completion_tokens_details': None,
#             'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0},
#             'prompt_cache_hit_tokens': 0,
#             'prompt_cache_miss_tokens': 10
#         },
#         'model_provider': 'deepseek',
#         'model_name': 'deepseek-v4-flash',
#         'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402',
#         'id': '56a51dcd-b36b-47f6-82a5-f109b8d7bf66',
#         'finish_reason': 'stop',
#         'logprobs': None
#     },
#     id='lc_run--019f6b18-c825-7a81-b0c7-cf9825cff298-0',
#     tool_calls=[],
#     invalid_tool_calls=[],
# ...

# %% [markdown]
# # Config(invoke, stream, batch)
